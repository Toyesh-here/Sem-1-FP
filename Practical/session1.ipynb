# %%
print("My name is Toyesh Goyal")
print("I am in NMIMS ")
print("I am studying Applied Mathematical Computing")

# %%
a = False
b = 18
c = 13.5
d = "Hello"

print("The value of w is:", a)
print("The value of x is:", b)
print("The value of y is:", c)
print("The value of z is:", d)
