# %%
student={'Name':'Toyesh Goyal', 'Course':'B.Sc. AMC', 'Sap id':86122600027, 'DOB':'19/05/2008', 'Blood Group':'O+', 'Contact':6356444030, 'Batch':'2026-30', 'College':'NMIMS'}
print(student.keys())
print(student.values())
print(student.pop('Blood Group'))
for key,value in student.items():
  print(key,"->",value)
st={'Department':'NSOMASA', 'Origin':'Surat'}
student.update(st)
print(student)

# %%
A={1,2,3,4}
B={3,4,5,6}
print(A|B)
print(A&B)
print(A-B)

# %%
age=int(input("Enter number: "))
print(18<=age<=60)
