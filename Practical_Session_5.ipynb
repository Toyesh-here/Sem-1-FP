# %% [markdown]
# <a href="https://colab.research.google.com/github/Toyesh-here/Sem-1-FP/blob/main/Practical_Session_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
UserId=1234567
Pass="Password"
User_Id=int(input("Enter user id: "))
if (UserId==User_Id):
  Pass_=(input("Enter Password: "))
  if (Pass==Pass_):
    Name=input("Enter name: ")
    Sap_Id=int(input("Enter sap id: "))
    Mobile=int(input("Enter Mobile number: "))
    Course=input("Enter Course: ")
    College=input("Enter College name: ")
  else :
    print("Wrong Password!!")
else :
  print("Wrong User id!!")
# Out:
# Enter user id: 1234567
# Enter Password: cbfdwv
# Wrong Password!!

# %%
Item_Name="Bottle"
Quantity=5
Price=799
Total=Quantity*Price
print(f"{'Item Name':<10}{'Quantity':>10}{'Price':>20}{'Total':>30}")
print(f"{Item_Name:<10}{Quantity:>10}{Price:>20}{Total:>30}")
print(f"{'Scissors':<10}{52:>10}{56:>20}{52*56:>30}")
print(f"{'China':<10}{355:>10}{745:>20}{355*745:>30}")
print(f"{'Tongs':<10}{35:>10}{65:>20}{35*65:>30}")
# Out:
# Item Name   Quantity               Price                         Total
# Bottle             5                 799                          3995
# Scissors          52                  56                          2912
# China            355                 745                        264475
# Tongs             35                  65                          2275

# %%
num = int(input("Enter a number: "))

if (num % 3 == 0) and (num % 5 == 0):
    print(f"{num} is divisible by both 3 and 5.")
elif num % 3 == 0:
    print(f"{num} is divisible by 3 but not by 5.")
elif num % 5 == 0:
    print(f"{num} is divisible by 5 but not by 3.")
else:
    print(f"{num} is not divisible by either 3 or 5.")
# Out:
# Enter a number: 758567848
# 758567848 is not divisible by either 3 or 5.
